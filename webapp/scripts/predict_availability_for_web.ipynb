# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
import numpy as np
import scipy as sp
import pandas as pd
import datetime
import mysql.connector
import os
import pytz
import simplejson as json
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ### Make the model to predict bike availability for the web

# %%
#### Gather historical data from the database so we don't have to make a bajillion calls while evaluating the model
## Get mysql credentials
mysql_host = os.getenv('JAWSDB_HOST')
mysql_username = os.getenv('JAWSDB_USERNAME')
mysql_password = os.getenv('JAWSDB_PASSWORD')
mysql_database = os.getenv('JAWSDB_DATABASE')

## Open database connection
mysqldb = mysql.connector.connect(host=mysql_host, user=mysql_username, passwd=mysql_password, db=mysql_database)
cur = mysqldb.cursor()

## Get station names
stations = []
cur.execute("SELECT `COLUMN_NAME` FROM `INFORMATION_SCHEMA`.`COLUMNS` WHERE `TABLE_SCHEMA`='"+str(mysql_database)+"' AND `TABLE_NAME`='station_availability';")
for entry in cur.fetchall():
    try:
        stations.append(int(entry[0]))
    except:
        continue

## Get timepoints and number of bikes at each station
cur.execute("SELECT * FROM station_availability;")
timepoints = []
values = []
for each in cur.fetchall():
    timepoints.append(each[0])
    values.append(each[1:])

## Create historical dataframe
df = pd.DataFrame(values, index = timepoints, columns = stations)
df.index = pd.to_datetime(df.index)
df.head()
# Out:
#                      31000  31001  31002  31003  31004  31005  31006  31007  \
# 2017-06-11 16:50:00      2      3     14     10      9     10      1      3
# 2017-06-11 17:00:00      2      3     14     10      9     10      1      3
# 2017-06-11 17:10:00      2      3     14     10      9     10      1      3
# 2017-06-11 17:20:00      2      3     14     10      9     10      1      3
# 2017-06-11 17:30:00      1      3     11      9      9     14      0      7
#
#                      31008  31009  ...    32217  32218  32219  32220  32221  \
# 2017-06-11 16:50:00      3      3  ...        5      6      7      4      8
# 2017-06-11 17:00:00      3      3  ...        5      6      7      4      8
# 2017-06-11 17:10:00      3      3  ...        5      6      7      4      8
# 2017-06-11 17:20:00      3      3  ...        5      6      7      4      8
# 2017-06-11 17:30:00      3      3  ...        5      6      7      4      8
#
#                      32222  32223  32224  32225  31924
# 2017-06-11 16:50:00      7      5      6      8    NaN
# 2017-06-11 17:00:00      7      5      6      8    NaN
# 2017-06-11 17:10:00      7      5      6      8    NaN
# 2017-06-11 17:20:00      7      5      6      8    NaN
# 2017-06-11 17:30:00      7      5      6      8    NaN
#
# [5 rows x 469 columns]

# %%
#### Now let's set up our evaluation metric
#### Since we care more about whether or not a user will be able to get a bike rather than how many bikes/docks are at each station this is really a binary classification problem.
#### The classes will be determined by a cutoff of 2 bikes/docks or more representing a "yes."
#### After our tests of various different models we saw that a simple linear regression that predicts the number of bikes performs similar to more advanced models in terms of R^2 and RMSE.
#### For speed's sake (since this is a webapp) we will use this linear regression and convert the prediction to a "yes" or "no" based on the cutoff value.
#### Our evaluation metric will thus just be classification accuracy since the problem is such a simple one.
def eval_metric(preds, actual_values, cutoff):
    scores = []
    for i in range(len(preds)):
        if (preds[i] >= cutoff and actual_values[i] >= cutoff) or (preds[i] < cutoff and actual_values[i] < cutoff):
            scores.append(1)
        else:
            scores.append(0)
    return float(scores.count(1))/len(scores)

# %% [markdown]
# ### Get stats for predictions across stations and time delays

# %%
def makePrediction(time_to_predict, station, time_difference):
    ## Convert time_to_predict into datetime
    datetime_to_predict = pd.to_datetime(time_to_predict)

    ## Get data for training the model
    ## Make date range to get values for the day a week prior to the query
    ############## USE THIS FOR TESTING UNTIL ENOUGH DATA ARE ACQUIRED, THEN CHANGE FROM 1 DAY TO 7 DAYS PRIOR ####################
    start_time = datetime_to_predict - datetime.timedelta(hours = 24)
    end_time = datetime_to_predict

    ## Make container for data
    train_Xs = []
    train_ys = []
    ## Get data from the dataframe for a station between two times passed in as datetime objects.
    temp_df = pd.DataFrame(df[start_time:end_time][station])
    temp_df.columns = ['y']
            
    ## Make lag features
    number_of_lags = 6
    ## Add lags
    for i in range(1,number_of_lags+1):
        temp_df['lag_'+str(10*i+time_difference)] = temp_df.y.shift(int(i+time_difference/10))
    ## Drop NAs
    temp_df.dropna(inplace = True, axis = 0)
    ## Return X and y values
    temp_Xs = temp_df.drop('y', axis = 1)
    temp_ys = temp_df.y

    ## Get data for making the prediction
    train_Xs = temp_Xs.iloc[:-1, :]
    train_ys = temp_ys.iloc[:-1]
    test_Xs = temp_Xs.iloc[-1, :]
    test_y = temp_ys.iloc[-1]
    
    features = train_Xs.columns
    
    ## Make a linear regression and train it on the previous day
    lr = LinearRegression()
    lr.fit(train_Xs, train_ys)
    ## Make a prediction for the time in question
    prediction = int(np.round(lr.predict(np.array(test_Xs).reshape(1,-1))))
    ## return the prediction and the actual value
    return prediction, test_y, lr, features

def makePlot(preds, actual_vals, coefs_list, feature_names, station, time_diff):
    ## Convert the list of arrays each with a single value to a list of values
    lr_variance = r2_score(actual_vals, preds)
    lr_rmse = np.sqrt(mean_squared_error(actual_vals, preds))
    lr_r = sp.stats.pearsonr(actual_vals, preds)[0]

    sns.set(font_scale = 2)
    fig = plt.figure(figsize = [18, 7])
    plt.subplot(1,3,1)
    plt.scatter(actual_vals, preds)
    plt.title('Predictions vs actual values')
    plt.ylabel('Predicted number of rides')
    plt.xlabel('Actual number of rides')
    plt.annotate('r = '+str(sp.stats.pearsonr(actual_vals, preds)[0])+"\nR^2 = "+str(lr_variance)+"\nRMSE = "+str(lr_rmse), xy=(0.01, 0.82), xycoords='axes fraction', size = 20)
    plt.tight_layout()
    plt.subplot(1,3,2)
    plt.plot(actual_vals)
    plt.plot(preds)
    plt.title('Bike availability over time')
    plt.xlabel('Time point index')
    plt.ylabel('Number of bikes\n(green = predicted)')
    plt.annotate('% accuracy = '+str(eval_metric(actual_vals, preds,2)), xy=(0.01, 0.94), xycoords='axes fraction', size = 20)
    plt.annotate('time difference = '+str(time_diff), xy=(0.01, 0.88), xycoords='axes fraction', size = 20)
    plt.subplot(1,3,3)
    coefs = pd.DataFrame([(x,y) for (y,x) in sorted(list(zip(np.abs(np.mean(np.array(coefs_list), axis = 0)), feature_names))[:], reverse = True)], 
                         columns = ['Feature', 'Importance (magnitude of coefficient)'])
    sns.barplot(x = 'Feature', y = 'Importance (magnitude of coefficient)', data = coefs)
    plt.xticks(rotation=90)
    plt.title('Average feature importance')
    plt.ylabel('Importance (magnitude of coefficient)')
    plt.tight_layout()
    plt.savefig('../figures/station_models/'+str(station)+'-'+str(time_diff)+'min.png', dpi = 300)

## Give a start time for predictions
start_time_to_predict = '2017-06-12 17:00'
## Give an end time for predictions
end_time_to_predict = '2017-06-14 17:00'
## Make a date range of dates to predict
date_range = pd.date_range(start = pd.to_datetime(start_time_to_predict), end = pd.to_datetime(end_time_to_predict), freq = '10min')
## Make a list of stations for which to make predictions (or just predict all in stations from before)
# stations_to_predict = [31623, 31304, 31520, 31242, 31207, 31204, 31635, 31019, 31919, 31047, 31004]
# stations_to_predict = [31623]
stations_to_predict = stations
## Make various time diffs
time_diffs = [10*i for i in range(1,7)]

evaluation = {}
## Make a prediction for various stations
init_time = datetime.datetime.now()
for i, prediction_station in enumerate(stations_to_predict):
    temp_dict = {}
    ## Make a prediction for a range of time diffs
    for prediction_time_diff in time_diffs:
        ## Make containers for relevant values for evaluation
        predictions = []
        test_ys = []
        coefs_list = []
        ## Make a prediction for each time in the date range
        for prediction_time in date_range:
            pred, actual_value, lr, features = makePrediction(prediction_time, prediction_station, prediction_time_diff)
            predictions.append(pred)
            test_ys.append(actual_value)
            coefs_list.append(lr.coef_)
            ## Add evaluations to dict of difference time diffs
        temp_dict[prediction_time_diff] = eval_metric(test_ys, predictions, 2)
        makePlot(predictions, test_ys, coefs_list, features, prediction_station, prediction_time_diff)
    evaluation[prediction_station] = temp_dict
    print('Done with station', i+1, 'of', len(stations_to_predict), '-', datetime.datetime.now() - init_time, 'since start.')
# Out:
# Done with station 1 of 469 - 0:00:07.807966 since start.
# Done with station 2 of 469 - 0:00:16.168600 since start.
# Done with station 3 of 469 - 0:00:24.431725 since start.
# Done with station 4 of 469 - 0:00:33.145416 since start.
# Done with station 5 of 469 - 0:00:41.576046 since start.
# Done with station 6 of 469 - 0:00:49.352728 since start.
# Done with station 7 of 469 - 0:00:57.038967 since start.
# Done with station 8 of 469 - 0:01:04.722449 since start.
# Done with station 9 of 469 - 0:01:13.295290 since start.
# Done with station 10 of 469 - 0:01:22.538064 since start.
# Done with station 11 of 469 - 0:01:31.287404 since start.
# Done with station 12 of 469 - 0:01:39.001437 since start.
# Done with station 13 of 469 - 0:01:47.457799 since start.
# Done with station 14 of 469 - 0:01:56.184408 since start.
# Done with station 15 of 469 - 0:02:06.119986 since start.
# Done with station 16 of 469 - 0:02:13.977875 since start.
# Done with station 17 of 469 - 0:02:22.262106 since start.
# Done with station 18 of 469 - 0:02:31.488886 since start.
# Done with station 19 of 469 - 0:02:39.999428 since start.
# Done with station 20 of 469 - 0:02:49.096037 since start.
# Done with station 21 of 469 - 0:03:00.009560 since start.
# Done with station 22 of 469 - 0:03:10.584557 since start.
# Done with station 23 of 469 - 0:03:22.084733 since start.
# Done with station 24 of 469 - 0:03:33.761525 since start.
# Done with station 25 of 469 - 0:03:43.770610 since start.
# Done with station 26 of 469 - 0:03:54.136807 since start.
# Done with station 27 of 469 - 0:04:04.017590 since start.
# Done with station 28 of 469 - 0:04:13.256278 since start.
# Done with station 29 of 469 - 0:04:23.051479 since start.
# Done with station 30 of 469 - 0:04:32.840200 since start.
# Done with station 31 of 469 - 0:04:42.635114 since start.
# Done with station 32 of 469 - 0:04:52.809086 since start.
# Done with station 33 of 469 - 0:05:02.532184 since start.
# Done with station 34 of 469 - 0:05:12.109221 since start.
# Done with station 35 of 469 - 0:05:21.968384 since start.
# Done with station 36 of 469 - 0:05:31.967227 since start.
# Done with station 37 of 469 - 0:05:41.798257 since start.
# Done with station 38 of 469 - 0:05:51.957874 since start.
# Done with station 39 of 469 - 0:06:02.782421 since start.
# Done with station 40 of 469 - 0:06:12.960095 since start.
# Done with station 41 of 469 - 0:06:22.684295 since start.
# Done with station 42 of 469 - 0:06:31.956564 since start.
# Done with station 43 of 469 - 0:06:40.564958 since start.
# Done with station 44 of 469 - 0:06:49.168153 since start.
# Done with station 45 of 469 - 0:06:57.934032 since start.
# Done with station 46 of 469 - 0:07:07.547910 since start.
# Done with station 47 of 469 - 0:07:16.607269 since start.
# Done with station 48 of 469 - 0:07:25.620168 since start.
# Done with station 49 of 469 - 0:07:34.417674 since start.
# Done with station 50 of 469 - 0:07:43.345389 since start.
# Done with station 51 of 469 - 0:07:52.141708 since start.
# Done with station 52 of 469 - 0:08:01.098108 since start.
# Done with station 53 of 469 - 0:08:09.920309 since start.
# Done with station 54 of 469 - 0:08:18.453293 since start.
# Done with station 55 of 469 - 0:08:27.106403 since start.
# Done with station 56 of 469 - 0:08:35.780725 since start.
# Done with station 57 of 469 - 0:08:44.727989 since start.
# Done with station 58 of 469 - 0:08:53.321873 since start.
# Done with station 59 of 469 - 0:09:01.735158 since start.
# Done with station 60 of 469 - 0:09:10.278496 since start.
# Done with station 61 of 469 - 0:09:18.990172 since start.
# Done with station 62 of 469 - 0:09:27.550811 since start.
# Done with station 63 of 469 - 0:09:35.996377 since start.
# Done with station 64 of 469 - 0:09:44.613533 since start.
# Done with station 65 of 469 - 0:09:52.916256 since start.
# Done with station 66 of 469 - 0:10:01.365330 since start.
# Done with station 67 of 469 - 0:10:10.599794 since start.
# Done with station 68 of 469 - 0:10:19.907024 since start.
# Done with station 69 of 469 - 0:10:28.641760 since start.
# Done with station 70 of 469 - 0:10:37.419715 since start.
# Done with station 71 of 469 - 0:10:46.512401 since start.
# Done with station 72 of 469 - 0:10:55.009402 since start.
# Done with station 73 of 469 - 0:11:03.730641 since start.
# Done with station 74 of 469 - 0:11:12.550732 since start.
# Done with station 75 of 469 - 0:11:21.027454 since start.
# Done with station 76 of 469 - 0:11:29.739431 since start.
# Done with station 77 of 469 - 0:11:38.125381 since start.
# Done with station 78 of 469 - 0:11:46.631311 since start.
# Done with station 79 of 469 - 0:11:56.118310 since start.
# Done with station 80 of 469 - 0:12:05.656212 since start.
# Done with station 81 of 469 - 0:12:14.041689 since start.
# Done with station 82 of 469 - 0:12:22.305958 since start.
# Done with station 83 of 469 - 0:12:30.876709 since start.
# Done with station 84 of 469 - 0:12:39.894123 since start.
# Done with station 85 of 469 - 0:12:48.236559 since start.
# Done with station 86 of 469 - 0:12:56.546698 since start.
# Done with station 87 of 469 - 0:13:04.871408 since start.
# Done with station 88 of 469 - 0:13:13.151472 since start.
# Done with station 89 of 469 - 0:13:21.575532 since start.
# Done with station 90 of 469 - 0:13:30.597809 since start.
# Done with station 91 of 469 - 0:13:39.494063 since start.
# Done with station 92 of 469 - 0:13:47.879158 since start.
# Done with station 93 of 469 - 0:13:56.984288 since start.
# Done with station 94 of 469 - 0:14:06.123437 since start.
# Done with station 95 of 469 - 0:14:15.138483 since start.
# Done with station 96 of 469 - 0:14:24.202701 since start.
# Done with station 97 of 469 - 0:14:33.338140 since start.
# Done with station 98 of 469 - 0:14:42.077104 since start.
# Done with station 99 of 469 - 0:14:50.499050 since start.
# Done with station 100 of 469 - 0:14:58.896653 since start.
# Done with station 101 of 469 - 0:15:07.278735 since start.
# Done with station 102 of 469 - 0:15:15.703255 since start.
# Done with station 103 of 469 - 0:15:24.164059 since start.
# Done with station 104 of 469 - 0:15:34.020499 since start.
# Done with station 105 of 469 - 0:15:42.843575 since start.
# Done with station 106 of 469 - 0:15:51.249447 since start.
# Done with station 107 of 469 - 0:15:59.824942 since start.
# Done with station 108 of 469 - 0:16:08.206161 since start.
# Done with station 109 of 469 - 0:16:16.584185 since start.
# Done with station 110 of 469 - 0:16:24.954958 since start.
# Done with station 111 of 469 - 0:16:33.477969 since start.
# Done with station 112 of 469 - 0:16:41.860270 since start.
# Done with station 113 of 469 - 0:16:50.470323 since start.
# Done with station 114 of 469 - 0:16:58.848867 since start.
# Done with station 115 of 469 - 0:17:07.217586 since start.
# Done with station 116 of 469 - 0:17:15.699497 since start.
# Done with station 117 of 469 - 0:17:24.199160 since start.
# Done with station 118 of 469 - 0:17:33.199801 since start.
# Done with station 119 of 469 - 0:17:41.772301 since start.
# Done with station 120 of 469 - 0:17:50.282533 since start.
# Done with station 121 of 469 - 0:17:59.076689 since start.
# Done with station 122 of 469 - 0:18:07.547002 since start.
# Done with station 123 of 469 - 0:18:16.008130 since start.
# Done with station 124 of 469 - 0:18:24.497036 since start.
# Done with station 125 of 469 - 0:18:33.048904 since start.
# Done with station 126 of 469 - 0:18:41.508613 since start.
# Done with station 127 of 469 - 0:18:49.993042 since start.
# Done with station 128 of 469 - 0:18:59.184662 since start.
# Done with station 129 of 469 - 0:19:08.762006 since start.
# Done with station 130 of 469 - 0:19:18.227668 since start.
# Done with station 131 of 469 - 0:19:27.939521 since start.
# Done with station 132 of 469 - 0:19:37.470958 since start.
# Done with station 133 of 469 - 0:19:47.060986 since start.
# Done with station 134 of 469 - 0:19:56.495963 since start.
# Done with station 135 of 469 - 0:20:05.981182 since start.
# Done with station 136 of 469 - 0:20:15.368358 since start.
# Done with station 137 of 469 - 0:20:24.805493 since start.
# Done with station 138 of 469 - 0:20:34.269225 since start.
# Done with station 139 of 469 - 0:20:43.691049 since start.
# Done with station 140 of 469 - 0:20:53.062846 since start.
# Done with station 141 of 469 - 0:21:02.530520 since start.
# Done with station 142 of 469 - 0:21:11.894245 since start.
# Done with station 143 of 469 - 0:21:21.281143 since start.
# Done with station 144 of 469 - 0:21:30.904524 since start.
# Done with station 145 of 469 - 0:21:40.347667 since start.
# Done with station 146 of 469 - 0:21:49.701423 since start.
# Done with station 147 of 469 - 0:21:59.135957 since start.
# Done with station 148 of 469 - 0:22:07.978451 since start.
# Done with station 149 of 469 - 0:22:16.419632 since start.
# Done with station 150 of 469 - 0:22:24.857425 since start.
# Done with station 151 of 469 - 0:22:33.431828 since start.
# Done with station 152 of 469 - 0:22:41.881595 since start.
# Done with station 153 of 469 - 0:22:50.119146 since start.
# Done with station 154 of 469 - 0:22:58.461297 since start.
# Done with station 155 of 469 - 0:23:06.886936 since start.
# Done with station 156 of 469 - 0:23:15.708275 since start.
# Done with station 157 of 469 - 0:23:24.719104 since start.
# Done with station 158 of 469 - 0:23:33.382162 since start.
# Done with station 159 of 469 - 0:23:41.857129 since start.
# Done with station 160 of 469 - 0:23:51.200232 since start.
# Done with station 161 of 469 - 0:24:00.362460 since start.
# Done with station 162 of 469 - 0:24:09.421471 since start.
# Done with station 163 of 469 - 0:24:18.937902 since start.
# Done with station 164 of 469 - 0:24:27.361902 since start.
# Done with station 165 of 469 - 0:24:36.055797 since start.
# Done with station 166 of 469 - 0:24:45.152356 since start.
# Done with station 167 of 469 - 0:24:54.963886 since start.
# Done with station 168 of 469 - 0:25:04.149224 since start.
# Done with station 169 of 469 - 0:25:12.930238 since start.
# Done with station 170 of 469 - 0:25:21.889550 since start.
# Done with station 171 of 469 - 0:25:30.664577 since start.
# Done with station 172 of 469 - 0:25:39.214166 since start.
# Done with station 173 of 469 - 0:25:47.843332 since start.
# Done with station 174 of 469 - 0:25:56.344282 since start.
# Done with station 175 of 469 - 0:26:04.996885 since start.
# Done with station 176 of 469 - 0:26:13.576286 since start.
# Done with station 177 of 469 - 0:26:22.777742 since start.
# Done with station 178 of 469 - 0:26:31.914733 since start.
# Done with station 179 of 469 - 0:26:40.647120 since start.
# Done with station 180 of 469 - 0:26:49.326195 since start.
# Done with station 181 of 469 - 0:26:58.200171 since start.
# Done with station 182 of 469 - 0:27:07.418176 since start.
# Done with station 183 of 469 - 0:27:16.007584 since start.
# Done with station 184 of 469 - 0:27:24.455282 since start.
# Done with station 185 of 469 - 0:27:33.100474 since start.
# Done with station 186 of 469 - 0:27:41.619768 since start.
# Done with station 187 of 469 - 0:27:50.229434 since start.
# Done with station 188 of 469 - 0:27:58.729536 since start.
# Done with station 189 of 469 - 0:28:07.316970 since start.
# Done with station 190 of 469 - 0:28:15.908145 since start.
# Done with station 191 of 469 - 0:28:24.214299 since start.
# Done with station 192 of 469 - 0:28:32.659864 since start.
# Done with station 193 of 469 - 0:28:40.965722 since start.
# Done with station 194 of 469 - 0:28:50.050098 since start.
# Done with station 195 of 469 - 0:28:59.411464 since start.
# Done with station 196 of 469 - 0:29:08.194573 since start.
# Done with station 197 of 469 - 0:29:17.260043 since start.
# Done with station 198 of 469 - 0:29:27.119895 since start.
# Done with station 199 of 469 - 0:29:36.580535 since start.
# Done with station 200 of 469 - 0:29:45.770885 since start.
# Done with station 201 of 469 - 0:29:55.014912 since start.
# Done with station 202 of 469 - 0:30:04.524822 since start.
# Done with station 203 of 469 - 0:30:13.215199 since start.
# Done with station 204 of 469 - 0:30:22.781726 since start.
# Done with station 205 of 469 - 0:30:32.239281 since start.
# Done with station 206 of 469 - 0:30:41.634736 since start.
# Done with station 207 of 469 - 0:30:51.208990 since start.
# Done with station 208 of 469 - 0:31:00.963740 since start.
# Done with station 209 of 469 - 0:31:10.753047 since start.
# Done with station 210 of 469 - 0:31:20.233527 since start.
# Done with station 211 of 469 - 0:31:30.194600 since start.
# Done with station 212 of 469 - 0:31:40.220929 since start.
# Done with station 213 of 469 - 0:31:50.428916 since start.
# Done with station 214 of 469 - 0:32:00.518018 since start.
# Done with station 215 of 469 - 0:32:10.002042 since start.
# Done with station 216 of 469 - 0:32:19.561475 since start.
# Done with station 217 of 469 - 0:32:29.080049 since start.
# Done with station 218 of 469 - 0:32:38.690332 since start.
# Done with station 219 of 469 - 0:32:48.179970 since start.
# Done with station 220 of 469 - 0:32:58.119003 since start.
# Done with station 221 of 469 - 0:33:08.257061 since start.
# Done with station 222 of 469 - 0:33:17.214991 since start.
# Done with station 223 of 469 - 0:33:26.524089 since start.
# Done with station 224 of 469 - 0:33:35.989311 since start.
# Done with station 225 of 469 - 0:33:45.654649 since start.
# Done with station 226 of 469 - 0:33:54.888553 since start.
# Done with station 227 of 469 - 0:34:04.303837 since start.
# Done with station 228 of 469 - 0:34:13.649184 since start.
# Done with station 229 of 469 - 0:34:23.304855 since start.
# Done with station 230 of 469 - 0:34:32.232902 since start.
# Done with station 231 of 469 - 0:34:41.110800 since start.
# Done with station 232 of 469 - 0:34:49.942915 since start.
# Done with station 233 of 469 - 0:34:59.820467 since start.
# Done with station 234 of 469 - 0:35:08.917921 since start.
# Done with station 235 of 469 - 0:35:17.884128 since start.
# Done with station 236 of 469 - 0:35:26.738880 since start.
# Done with station 237 of 469 - 0:35:35.545022 since start.
# Done with station 238 of 469 - 0:35:45.013087 since start.
# Done with station 239 of 469 - 0:35:55.278073 since start.
# Done with station 240 of 469 - 0:36:04.164938 since start.
# Done with station 241 of 469 - 0:36:13.293460 since start.
# Done with station 242 of 469 - 0:36:23.756374 since start.
# Done with station 243 of 469 - 0:36:33.324785 since start.
# Done with station 244 of 469 - 0:36:42.552161 since start.
# Done with station 245 of 469 - 0:36:51.283425 since start.
# Done with station 246 of 469 - 0:37:00.617982 since start.
# Done with station 247 of 469 - 0:37:10.010564 since start.
# Done with station 248 of 469 - 0:37:19.490442 since start.
# Done with station 249 of 469 - 0:37:30.279931 since start.
# Done with station 250 of 469 - 0:37:40.947306 since start.
# Done with station 251 of 469 - 0:37:51.359885 since start.
# Done with station 252 of 469 - 0:38:02.309743 since start.
# Done with station 253 of 469 - 0:38:11.409348 since start.
# Done with station 254 of 469 - 0:38:20.605235 since start.
# Done with station 255 of 469 - 0:38:30.514885 since start.
# Done with station 256 of 469 - 0:38:39.438646 since start.
# Done with station 257 of 469 - 0:38:48.544759 since start.
# Done with station 258 of 469 - 0:38:57.228215 since start.
# Done with station 259 of 469 - 0:39:06.598914 since start.
# Done with station 260 of 469 - 0:39:16.592412 since start.
# Done with station 261 of 469 - 0:39:26.394656 since start.
# Done with station 262 of 469 - 0:39:36.037376 since start.
# Done with station 263 of 469 - 0:39:45.544545 since start.
# Done with station 264 of 469 - 0:39:55.305809 since start.
# Done with station 265 of 469 - 0:40:04.867642 since start.
# Done with station 266 of 469 - 0:40:14.304202 since start.
# Done with station 267 of 469 - 0:40:23.284177 since start.
# Done with station 268 of 469 - 0:40:32.935738 since start.
# Done with station 269 of 469 - 0:40:42.357703 since start.
# Done with station 270 of 469 - 0:40:51.950287 since start.
# Done with station 271 of 469 - 0:41:00.610106 since start.
# Done with station 272 of 469 - 0:41:10.590498 since start.
# Done with station 273 of 469 - 0:41:20.489946 since start.
# Done with station 274 of 469 - 0:41:30.863221 since start.
# Done with station 275 of 469 - 0:41:40.187892 since start.
# Done with station 276 of 469 - 0:41:48.830692 since start.
# Done with station 277 of 469 - 0:41:58.165230 since start.
# Done with station 278 of 469 - 0:42:06.902105 since start.
# Done with station 279 of 469 - 0:42:16.115562 since start.
# Done with station 280 of 469 - 0:42:25.361094 since start.
# Done with station 281 of 469 - 0:42:34.335227 since start.
# Done with station 282 of 469 - 0:42:43.619621 since start.
# Done with station 283 of 469 - 0:42:52.354117 since start.
# Done with station 284 of 469 - 0:43:01.689840 since start.
# Done with station 285 of 469 - 0:43:11.029327 since start.
# Done with station 286 of 469 - 0:43:19.699249 since start.
# Done with station 287 of 469 - 0:43:28.892853 since start.
# Done with station 288 of 469 - 0:43:37.642201 since start.
# Done with station 289 of 469 - 0:43:47.258763 since start.
# Done with station 290 of 469 - 0:43:56.266771 since start.
# Done with station 291 of 469 - 0:44:04.672520 since start.
# Done with station 292 of 469 - 0:44:13.833006 since start.
# Done with station 293 of 469 - 0:44:22.561874 since start.
# Done with station 294 of 469 - 0:44:31.489610 since start.
# Done with station 295 of 469 - 0:44:40.911458 since start.
# Done with station 296 of 469 - 0:44:50.177328 since start.
# Done with station 297 of 469 - 0:44:59.013715 since start.
# Done with station 298 of 469 - 0:45:07.860427 since start.
# Done with station 299 of 469 - 0:45:17.018134 since start.
# Done with station 300 of 469 - 0:45:25.881587 since start.
# Done with station 301 of 469 - 0:45:35.059510 since start.
# Done with station 302 of 469 - 0:45:44.200149 since start.
# Done with station 303 of 469 - 0:45:53.653706 since start.
# Done with station 304 of 469 - 0:46:04.018151 since start.
# Done with station 305 of 469 - 0:46:13.902706 since start.
# Done with station 306 of 469 - 0:46:22.760136 since start.
# Done with station 307 of 469 - 0:46:32.757728 since start.
# Done with station 308 of 469 - 0:46:41.937859 since start.
# Done with station 309 of 469 - 0:46:51.848516 since start.
# Done with station 310 of 469 - 0:47:01.594489 since start.
# Done with station 311 of 469 - 0:47:11.212905 since start.
# Done with station 312 of 469 - 0:47:20.462471 since start.
# Done with station 313 of 469 - 0:47:30.254678 since start.
# Done with station 314 of 469 - 0:47:40.069265 since start.
# Done with station 315 of 469 - 0:47:49.647145 since start.
# Done with station 316 of 469 - 0:47:59.294219 since start.
# Done with station 317 of 469 - 0:48:09.036794 since start.
# Done with station 318 of 469 - 0:48:18.714002 since start.
# Done with station 319 of 469 - 0:48:28.791493 since start.
# Done with station 320 of 469 - 0:48:38.281955 since start.
# Done with station 321 of 469 - 0:48:47.797890 since start.
# Done with station 322 of 469 - 0:48:57.237833 since start.
# Done with station 323 of 469 - 0:49:06.661148 since start.
# Done with station 324 of 469 - 0:49:16.584005 since start.
# Done with station 325 of 469 - 0:49:26.588788 since start.
# Done with station 326 of 469 - 0:49:36.850842 since start.
# Done with station 327 of 469 - 0:49:47.646104 since start.
# Done with station 328 of 469 - 0:49:58.179929 since start.
# Done with station 329 of 469 - 0:50:08.005884 since start.
# Done with station 330 of 469 - 0:50:18.391371 since start.
# Done with station 331 of 469 - 0:50:28.217186 since start.
# Done with station 332 of 469 - 0:50:37.978599 since start.
# Done with station 333 of 469 - 0:50:47.592498 since start.
# Done with station 334 of 469 - 0:50:57.121347 since start.
# Done with station 335 of 469 - 0:51:07.116351 since start.
# Done with station 336 of 469 - 0:51:16.712036 since start.
# Done with station 337 of 469 - 0:51:26.661044 since start.
# Done with station 338 of 469 - 0:51:36.335795 since start.
# Done with station 339 of 469 - 0:51:45.881289 since start.
# Done with station 340 of 469 - 0:51:55.215146 since start.
# Done with station 341 of 469 - 0:52:04.682432 since start.
# Done with station 342 of 469 - 0:52:14.349938 since start.
# Done with station 343 of 469 - 0:52:24.204928 since start.
# Done with station 344 of 469 - 0:52:33.858386 since start.
# Done with station 345 of 469 - 0:52:43.279992 since start.
# Done with station 346 of 469 - 0:52:52.869059 since start.
# Done with station 347 of 469 - 0:53:02.529412 since start.
# Done with station 348 of 469 - 0:53:12.122039 since start.
# Done with station 349 of 469 - 0:53:21.644094 since start.
# Done with station 350 of 469 - 0:53:31.884020 since start.
# Done with station 351 of 469 - 0:53:41.711615 since start.
# Done with station 352 of 469 - 0:53:51.182759 since start.
# Done with station 353 of 469 - 0:54:00.154541 since start.
# Done with station 354 of 469 - 0:54:09.376986 since start.
# Done with station 355 of 469 - 0:54:18.188037 since start.
# Done with station 356 of 469 - 0:54:26.624804 since start.
# Done with station 357 of 469 - 0:54:35.364204 since start.
# Done with station 358 of 469 - 0:54:44.761559 since start.
# Done with station 359 of 469 - 0:54:53.983090 since start.
# Done with station 360 of 469 - 0:55:02.409505 since start.
# Done with station 361 of 469 - 0:55:10.901132 since start.
# Done with station 362 of 469 - 0:55:19.755704 since start.
# Done with station 363 of 469 - 0:55:28.264832 since start.
# Done with station 364 of 469 - 0:55:37.276170 since start.
# Done with station 365 of 469 - 0:55:46.157342 since start.
# Done with station 366 of 469 - 0:55:55.387685 since start.
# Done with station 367 of 469 - 0:56:05.110008 since start.
# Done with station 368 of 469 - 0:56:14.378341 since start.
# Done with station 369 of 469 - 0:56:23.953003 since start.
# Done with station 370 of 469 - 0:56:33.757667 since start.
# Done with station 371 of 469 - 0:56:42.900924 since start.
# Done with station 372 of 469 - 0:56:51.970237 since start.
# Done with station 373 of 469 - 0:57:01.166155 since start.
# Done with station 374 of 469 - 0:57:09.659186 since start.
# Done with station 375 of 469 - 0:57:18.513434 since start.
# Done with station 376 of 469 - 0:57:27.207690 since start.
# Done with station 377 of 469 - 0:57:36.211448 since start.
# Done with station 378 of 469 - 0:57:45.067539 since start.
# Done with station 379 of 469 - 0:57:53.674265 since start.
# Done with station 380 of 469 - 0:58:02.405949 since start.
# Done with station 381 of 469 - 0:58:11.015277 since start.
# Done with station 382 of 469 - 0:58:19.482070 since start.
# Done with station 383 of 469 - 0:58:27.909053 since start.
# Done with station 384 of 469 - 0:58:36.297231 since start.
# Done with station 385 of 469 - 0:58:44.762554 since start.
# Done with station 386 of 469 - 0:58:53.150965 since start.
# Done with station 387 of 469 - 0:59:01.552016 since start.
# Done with station 388 of 469 - 0:59:09.943130 since start.
# Done with station 389 of 469 - 0:59:18.530154 since start.
# Done with station 390 of 469 - 0:59:27.152658 since start.
# Done with station 391 of 469 - 0:59:35.859367 since start.
# Done with station 392 of 469 - 0:59:44.367144 since start.
# Done with station 393 of 469 - 0:59:52.951243 since start.
# Done with station 394 of 469 - 1:00:02.883488 since start.
# Done with station 395 of 469 - 1:00:12.007133 since start.
# Done with station 396 of 469 - 1:00:21.713269 since start.
# Done with station 397 of 469 - 1:00:30.339842 since start.
# Done with station 398 of 469 - 1:00:39.110678 since start.
# Done with station 399 of 469 - 1:00:47.605108 since start.
# Done with station 400 of 469 - 1:00:56.256128 since start.
# Done with station 401 of 469 - 1:01:04.732218 since start.
# Done with station 402 of 469 - 1:01:13.395327 since start.
# Done with station 403 of 469 - 1:01:21.898548 since start.
# Done with station 404 of 469 - 1:01:30.462013 since start.
# Done with station 405 of 469 - 1:01:38.760598 since start.
# Done with station 406 of 469 - 1:01:46.935447 since start.
# Done with station 407 of 469 - 1:01:55.153429 since start.
# Done with station 408 of 469 - 1:02:03.500712 since start.
# Done with station 409 of 469 - 1:02:11.701422 since start.
# Done with station 410 of 469 - 1:02:20.114704 since start.
# Done with station 411 of 469 - 1:02:28.567250 since start.
# Done with station 412 of 469 - 1:02:37.055794 since start.
# Done with station 413 of 469 - 1:02:45.586179 since start.
# Done with station 414 of 469 - 1:02:53.926397 since start.
# Done with station 415 of 469 - 1:03:02.304416 since start.
# Done with station 416 of 469 - 1:03:10.748618 since start.
# Done with station 417 of 469 - 1:03:19.152790 since start.
# Done with station 418 of 469 - 1:03:27.990974 since start.
# Done with station 419 of 469 - 1:03:36.561198 since start.
# Done with station 420 of 469 - 1:03:46.015689 since start.
# Done with station 421 of 469 - 1:03:55.678684 since start.
# Done with station 422 of 469 - 1:04:05.091149 since start.
# Done with station 423 of 469 - 1:04:14.406004 since start.
# Done with station 424 of 469 - 1:04:23.775658 since start.
# Done with station 425 of 469 - 1:04:33.358578 since start.
# Done with station 426 of 469 - 1:04:43.038492 since start.
# Done with station 427 of 469 - 1:04:52.721851 since start.
# Done with station 428 of 469 - 1:05:03.214224 since start.
# Done with station 429 of 469 - 1:05:12.525666 since start.
# Done with station 430 of 469 - 1:05:21.083856 since start.
# Done with station 431 of 469 - 1:05:29.628525 since start.
# Done with station 432 of 469 - 1:05:38.188120 since start.
# Done with station 433 of 469 - 1:05:46.606460 since start.
# Done with station 434 of 469 - 1:05:55.240627 since start.
# Done with station 435 of 469 - 1:06:04.496931 since start.
# Done with station 436 of 469 - 1:06:13.886874 since start.
# Done with station 437 of 469 - 1:06:22.446468 since start.
# Done with station 438 of 469 - 1:06:30.626055 since start.
# Done with station 439 of 469 - 1:06:38.866860 since start.
# Done with station 440 of 469 - 1:06:47.496976 since start.
# Done with station 441 of 469 - 1:06:55.866205 since start.
# Done with station 442 of 469 - 1:07:04.355014 since start.
# Done with station 443 of 469 - 1:07:12.994605 since start.
# Done with station 444 of 469 - 1:07:22.171409 since start.
# Done with station 445 of 469 - 1:07:31.165836 since start.
# Done with station 446 of 469 - 1:07:40.813880 since start.
# Done with station 447 of 469 - 1:07:49.981395 since start.
# Done with station 448 of 469 - 1:07:59.103816 since start.
# Done with station 449 of 469 - 1:08:07.700798 since start.
# Done with station 450 of 469 - 1:08:16.010144 since start.
# Done with station 451 of 469 - 1:08:24.341921 since start.
# Done with station 452 of 469 - 1:08:32.660117 since start.
# Done with station 453 of 469 - 1:08:41.198564 since start.
# Done with station 454 of 469 - 1:08:50.116587 since start.
# Done with station 455 of 469 - 1:08:59.242459 since start.
# Done with station 456 of 469 - 1:09:07.812932 since start.
# Done with station 457 of 469 - 1:09:16.098444 since start.
# Done with station 458 of 469 - 1:09:24.568020 since start.
# Done with station 459 of 469 - 1:09:34.068895 since start.
# Done with station 460 of 469 - 1:09:44.304870 since start.
# Done with station 461 of 469 - 1:09:53.818871 since start.
# Done with station 462 of 469 - 1:10:02.677920 since start.
# Done with station 463 of 469 - 1:10:11.587214 since start.
# Done with station 464 of 469 - 1:10:21.179880 since start.
# Done with station 465 of 469 - 1:10:30.476515 since start.
# Done with station 466 of 469 - 1:10:40.996258 since start.
# Done with station 467 of 469 - 1:10:50.174047 since start.
# Done with station 468 of 469 - 1:10:58.925981 since start.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-367afa894816> in <module>()
#     102         ## Make a prediction for each time in the date range
#     103         for prediction_time in date_range:
# --> 104             pred, actual_value, lr, features = makePrediction(prediction_time, prediction_station, prediction_time_diff)
#     105             predictions.append(pred)
#     106             test_ys.append(actual_value)
#
# <ipython-input-24-367afa894816> in makePrediction(time_to_predict, station, time_difference)
#      30     train_Xs = temp_Xs.iloc[:-1, :]
#      31     train_ys = temp_ys.iloc[:-1]
# ---> 32     test_Xs = temp_Xs.iloc[-1, :]
#      33     test_y = temp_ys.iloc[-1]
#      34
#
# /usr/lib64/python3.5/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# /usr/lib64/python3.5/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1660     def _getitem_tuple(self, tup):
#    1661
# -> 1662         self._has_valid_tuple(tup)
#    1663         try:
#    1664             return self._getitem_lowerdim(tup)
#
# /usr/lib64/python3.5/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
#     187             if i >= self.obj.ndim:
#     188                 raise IndexingError('Too many indexers')
# --> 189             if not self._has_valid_type(k, i):
#     190                 raise ValueError("Location based indexing can only have [%s] "
#     191                                  "types" % self._valid_types)
#
# /usr/lib64/python3.5/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1595             return True
#    1596         elif is_integer(key):
# -> 1597             return self._is_valid_integer(key, axis)
#    1598         elif is_list_like_indexer(key):
#    1599             return self._is_valid_list_like(key, axis)
#
# /usr/lib64/python3.5/site-packages/pandas/core/indexing.py in _is_valid_integer(self, key, axis)
#    1636         l = len(ax)
#    1637         if key >= l or key < -l:
# -> 1638             raise IndexError("single positional indexer is out-of-bounds")
#    1639         return True
#    1640
#
# IndexError: single positional indexer is out-of-bounds

# %%
## Let's look at some stats of the scores
eval_df = pd.DataFrame(evaluation)
eval_df.to_csv('../data/single_model_evaluation_data.csv')
eval_df
# Out:
#     31000  31001  31002     31003     31004     31005  31006     31007  \
# 10    1.0    1.0    1.0  0.982699  0.986159  0.993080    1.0  0.972318
# 20    1.0    1.0    1.0  0.979239  0.972318  0.986159    1.0  0.965398
# 30    1.0    1.0    1.0  0.979239  0.965398  0.986159    1.0  0.961938
# 40    1.0    1.0    1.0  0.979239  0.958478  0.982699    1.0  0.958478
# 50    1.0    1.0    1.0  0.975779  0.951557  0.982699    1.0  0.958478
# 60    1.0    1.0    1.0  0.968858  0.944637  0.982699    1.0  0.955017
#
#        31008  31009  ...    32216     32217  32218  32219  32220  32221  \
# 10  0.965398    1.0  ...      1.0  0.986159    1.0    1.0    1.0    1.0
# 20  0.937716    1.0  ...      1.0  0.979239    1.0    1.0    1.0    1.0
# 30  0.910035    1.0  ...      1.0  0.972318    1.0    1.0    1.0    1.0
# 40  0.885813    1.0  ...      1.0  0.965398    1.0    1.0    1.0    1.0
# 50  0.878893    1.0  ...      1.0  0.958478    1.0    1.0    1.0    1.0
# 60  0.878893    1.0  ...      1.0  0.951557    1.0    1.0    1.0    1.0
#
#     32222  32223  32224  32225
# 10    1.0    1.0    1.0    1.0
# 20    1.0    1.0    1.0    1.0
# 30    1.0    1.0    1.0    1.0
# 40    1.0    1.0    1.0    1.0
# 50    1.0    1.0    1.0    1.0
# 60    1.0    1.0    1.0    1.0
#
# [6 rows x 468 columns]

# %%
eval_df = pd.read_csv('../data/single_model_evaluation_data.csv', index_col = 0)
eval_df
# Out:
#     31000  31001  31002     31003     31004     31005  31006     31007  \
# 10    1.0    1.0    1.0  0.982699  0.986159  0.993080    1.0  0.972318
# 20    1.0    1.0    1.0  0.979239  0.972318  0.986159    1.0  0.965398
# 30    1.0    1.0    1.0  0.979239  0.965398  0.986159    1.0  0.961938
# 40    1.0    1.0    1.0  0.979239  0.958478  0.982699    1.0  0.958478
# 50    1.0    1.0    1.0  0.975779  0.951557  0.982699    1.0  0.958478
# 60    1.0    1.0    1.0  0.968858  0.944637  0.982699    1.0  0.955017
#
#        31008  31009  ...    32216     32217  32218  32219  32220  32221  \
# 10  0.965398    1.0  ...      1.0  0.986159    1.0    1.0    1.0    1.0
# 20  0.937716    1.0  ...      1.0  0.979239    1.0    1.0    1.0    1.0
# 30  0.910035    1.0  ...      1.0  0.972318    1.0    1.0    1.0    1.0
# 40  0.885813    1.0  ...      1.0  0.965398    1.0    1.0    1.0    1.0
# 50  0.878893    1.0  ...      1.0  0.958478    1.0    1.0    1.0    1.0
# 60  0.878893    1.0  ...      1.0  0.951557    1.0    1.0    1.0    1.0
#
#     32222  32223  32224  32225
# 10    1.0    1.0    1.0    1.0
# 20    1.0    1.0    1.0    1.0
# 30    1.0    1.0    1.0    1.0
# 40    1.0    1.0    1.0    1.0
# 50    1.0    1.0    1.0    1.0
# 60    1.0    1.0    1.0    1.0
#
# [6 rows x 468 columns]

# %% [markdown]
# ### The model makes very similar classification predictions across time differences

# %%
## standard deviation across time differences is small
print(eval_df.std().median())
eval_df.std().hist()
# Out:
# 0.015114834311596003

# %% [markdown]
# ### The model's accuracy varies between stations but on average is high

# %%
## Average score
print('Median accuracy =', eval_df.median().median())
print('Minimum accuracy =', eval_df.min().min())
## Distribution of scores for 0 time differences
# %matplotlib inline
eval_df.T.hist(bins = 20, figsize = [20, 10])
# Out:
# Median accuracy = 0.9411764705882353
# Minimum accuracy = 0.491349480969
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff5c8ba98d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff5ca6d9da0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff5c72ed0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff5c2d78da0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7ff5c42c9780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7ff5c9cd7358>]], dtype=object)

# %%
## Since the model is generally pretty good we'll use this iteration for the webapp
