# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import scipy as sp
import mysql.connector
import os
import simplejson as json

## Import the libraries for modeling
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error, r2_score, accuracy_score
from autosklearn.regression import AutoSklearnRegressor

# %% [markdown]
# ## Note concerning weather features

# %%
#### I included weather features in the initial testing of these models, and they were seen to be less predictive than simple time lags.
#### While weather features slightly improved the SVC and random forest models they did not push those models over the edge to become better than the linear regression model.
#### Furthermore, they did not improve the linear regression model enough to warrant the extra computation time needed for the heavier model.
#### Due to these reasons and for the sake of brevity I have left out the analyses with the weather features and only included those with time lags.

# %%
#### Gather historical data from the database so we don't have to make a bajillion calls while evaluating the model
## Get mysql credentials
mysql_host = os.getenv('JAWSDB_HOST')
mysql_username = os.getenv('JAWSDB_USERNAME')
mysql_password = os.getenv('JAWSDB_PASSWORD')
mysql_database = os.getenv('JAWSDB_DATABASE')

## Open database connection
mysqldb = mysql.connector.connect(host=mysql_host, user=mysql_username, passwd=mysql_password, db=mysql_database)
cur = mysqldb.cursor()

## Get station names
stations = []
cur.execute("SELECT `COLUMN_NAME` FROM `INFORMATION_SCHEMA`.`COLUMNS` WHERE `TABLE_SCHEMA`='"+str(mysql_database)+"' AND `TABLE_NAME`='station_availability';")
for entry in cur.fetchall():
    try:
        stations.append(int(entry[0]))
    except:
        continue

## Get timepoints and number of bikes at each station
cur.execute("SELECT * FROM station_availability;")
timepoints = []
values = []
for each in cur.fetchall():
    timepoints.append(each[0])
    values.append(each[1:])

## Create historical dataframe
df = pd.DataFrame(values, index = timepoints, columns = stations)
df.index = pd.to_datetime(df.index)
df.head()
# Out:
#                      31000  31001  31002  31003  31004  31005  31006  31007  \
# 2017-06-11 16:50:00      2      3     14     10      9     10      1      3
# 2017-06-11 17:00:00      2      3     14     10      9     10      1      3
# 2017-06-11 17:10:00      2      3     14     10      9     10      1      3
# 2017-06-11 17:20:00      2      3     14     10      9     10      1      3
# 2017-06-11 17:30:00      1      3     11      9      9     14      0      7
#
#                      31008  31009  ...    32217  32218  32219  32220  32221  \
# 2017-06-11 16:50:00      3      3  ...        5      6      7      4      8
# 2017-06-11 17:00:00      3      3  ...        5      6      7      4      8
# 2017-06-11 17:10:00      3      3  ...        5      6      7      4      8
# 2017-06-11 17:20:00      3      3  ...        5      6      7      4      8
# 2017-06-11 17:30:00      3      3  ...        5      6      7      4      8
#
#                      32222  32223  32224  32225  31924
# 2017-06-11 16:50:00      7      5      6      8    NaN
# 2017-06-11 17:00:00      7      5      6      8    NaN
# 2017-06-11 17:10:00      7      5      6      8    NaN
# 2017-06-11 17:20:00      7      5      6      8    NaN
# 2017-06-11 17:30:00      7      5      6      8    NaN
#
# [5 rows x 469 columns]

# %%
#### Now let's set up our evaluation metric
#### Since we care more about whether or not a user will be able to get a bike rather than how many bikes/docks are at each station this is really a binary classification problem.
#### In order to have a more granular idea of how our model performs, however, we do still want to see how well our model predicts the number of bikes.
#### To this end we'll set up a regression model and use an eval metric to effectively make it a classification problem.
#### We can compare this to classifiers.
#### The classes will be determined by a cutoff of 2 bikes/docks or more representing a "yes."
#### Our evaluation metric will thus just be classification accuracy since the problem is such a simple one.
def eval_metric(preds, actual_values, cutoff):
    scores = []
    for i in range(len(preds)):
        if (preds[i] >= cutoff and actual_values[i] >= cutoff) or (preds[i] < cutoff and actual_values[i] < cutoff):
            scores.append(1)
        else:
            scores.append(0)
    return float(scores.count(1))/len(scores)

# %% [markdown]
# ### Set up the regression model

# %%
def makePrediction(time_to_predict, station, time_difference):
    ## Convert time_to_predict into datetime
    datetime_to_predict = pd.to_datetime(time_to_predict)

    ## Get data for training the model
    ## Make date range to get values for the day a week prior to the query
    ############## USE THIS FOR TESTING UNTIL ENOUGH DATA ARE ACQUIRED, THEN CHANGE FROM 1 DAY TO 7 DAYS PRIOR ####################
    start_time = datetime_to_predict - datetime.timedelta(hours = 24)
    end_time = datetime_to_predict

    ## Make container for data
    train_Xs = []
    train_ys = []
    ## Get data from the dataframe for a station between two times passed in as datetime objects.
    temp_df = pd.DataFrame(df[start_time:end_time][station])
    temp_df.columns = ['y']
            
    ## Make lag features
    number_of_lags = 6
    ## Add lags
    for i in range(1,number_of_lags+1):
        temp_df['lag_'+str(10*i+time_difference)] = temp_df.y.shift(int(i+time_difference/10))
    ## Drop NAs
    temp_df.dropna(inplace = True, axis = 0)
    ## Return X and y values
    temp_Xs = temp_df.drop('y', axis = 1)
    temp_ys = temp_df.y

    ## Get data for making the prediction
    train_Xs = temp_Xs.iloc[:-1, :]
    train_ys = temp_ys.iloc[:-1]
    test_Xs = temp_Xs.iloc[-1, :]
    test_y = temp_ys.iloc[-1]
    
    features = train_Xs.columns
    
    ## Make a linear regression and train it on the previous day
    lr = LinearRegression()
    lr.fit(train_Xs, train_ys)
    ## Make a prediction for the time in question
    prediction = int(np.round(lr.predict(np.array(test_Xs).reshape(1,-1))))
    ## return the prediction and the actual value
    return prediction, test_y, lr, features

def makePlot(preds, actual_vals, coefs_list, feature_names):
    ## Convert the list of arrays each with a single value to a list of values
    lr_variance = r2_score(actual_vals, preds)
    lr_rmse = np.sqrt(mean_squared_error(actual_vals, preds))
    lr_r = sp.stats.pearsonr(actual_vals, preds)[0]

    sns.set(font_scale = 2)
    fig = plt.figure(figsize = [18, 7])
    plt.subplot(1,3,1)
    plt.scatter(actual_vals, preds)
    plt.title('Predictions vs actual values')
    plt.ylabel('Predicted number of rides')
    plt.xlabel('Actual number of rides')
    plt.annotate('r = '+str(sp.stats.pearsonr(actual_vals, preds)[0])+"\nR^2 = "+str(lr_variance)+"\nRMSE = "+str(lr_rmse), xy=(0.05, 0.78), xycoords='axes fraction', size = 20)
    plt.tight_layout()
    plt.subplot(1,3,2)
    plt.plot(actual_vals)
    plt.plot(preds)
    plt.title('Bike availability over time')
    plt.xlabel('Time point index')
    plt.ylabel('Number of bikes\n(green = predicted)')
    plt.annotate('% accuracy = '+str(eval_metric(actual_vals, preds,2)), xy=(0.05, 0.94), xycoords='axes fraction', size = 20)
    plt.subplot(1,3,3)
    coefs = pd.DataFrame([(x,y) for (y,x) in sorted(list(zip(np.abs(np.mean(np.array(coefs_list), axis = 0)), feature_names))[:], reverse = True)], 
                         columns = ['Feature', 'Importance (magnitude of coefficient)'])
    sns.barplot(x = 'Feature', y = 'Importance (magnitude of coefficient)', data = coefs)
    plt.xticks(rotation=90)
    plt.title('Average feature importance')
    plt.ylabel('Importance (magnitude of coefficient)')
    plt.tight_layout()

## Give a start time for predictions
start_time_to_predict = '2017-06-12 17:00'
## Give an end time for predictions
end_time_to_predict = '2017-06-14 17:00'
## Make a date range of dates to predict
date_range = pd.date_range(start = pd.to_datetime(start_time_to_predict), end = pd.to_datetime(end_time_to_predict), freq = '10min')
## Make a list of stations for which to make predictions (or just predict all in stations from before)
# stations_to_predict = [31623, 31304, 31520, 31242, 31207, 31204, 31635, 31019, 31919, 31047, 31004]
stations_to_predict = [31623]
## Make various time diffs
time_diffs = [10*i for i in range(1,2)]

## Make containers for relevant values for evaluation
predictions = []
test_ys = []
coefs_list = []
## Make a prediction for various stations
init_time = datetime.datetime.now()
for i, prediction_station in enumerate(stations_to_predict):
    temp_dict = {}
    ## Make a prediction for a range of time diffs
    for prediction_time_diff in time_diffs:
        ## Make a prediction for each time in the date range
        for prediction_time in date_range:
            pred, actual_value, lr, features = makePrediction(prediction_time, prediction_station, prediction_time_diff)
            predictions.append(pred)
            test_ys.append(actual_value)
            coefs_list.append(lr.coef_)
    print('Done with station', i+1, 'of', len(stations_to_predict), '-', datetime.datetime.now() - init_time, 'since start.')

makePlot(predictions, test_ys, coefs_list, features)
# Out:
# Done with station 1 of 1 - 0:00:01.563359 since start.

# %% [markdown]
# ### Set up the classifier

# %%
## Make the data sets
def makeData(time_to_predict, station, time_difference):
    ## Convert time_to_predict into datetime
    datetime_to_predict = pd.to_datetime(time_to_predict)

    ## Get data for training the model
    ## Make date range to get values for the day a week prior to the query
    ############## USE THIS FOR TESTING UNTIL ENOUGH DATA ARE ACQUIRED, THEN CHANGE FROM 1 DAY TO 7 DAYS PRIOR ####################
    start_time = datetime_to_predict - datetime.timedelta(hours = 24)
    end_time = datetime_to_predict

    ## Make container for data
    train_Xs = []
    train_ys = []
    ## Get data from the dataframe for a station between two times passed in as datetime objects.
    temp_df = pd.DataFrame(df[start_time:end_time][station])
    temp_df.columns = ['y']
            
    ## Make lag features
    number_of_lags = 6
    ## Add lags
    for i in range(1,number_of_lags+1):
        temp_df['lag_'+str(10*i+time_difference)] = temp_df.y.shift(int(i+time_difference/10))
    ## Drop NAs
    temp_df.dropna(inplace = True, axis = 0)
    ## Return X and y values
    temp_Xs = temp_df.drop('y', axis = 1)
    temp_ys = temp_df.y
    temp_ys.loc[temp_ys < 2] = 0
    temp_ys.loc[temp_ys >= 2] = 1

    ## Get data for making the prediction
    train_Xs = temp_Xs.iloc[:-1, :]
    train_ys = temp_ys.iloc[:-1]
    test_Xs = temp_Xs.iloc[-1, :]
    test_y = temp_ys.iloc[-1]
        
    return train_Xs, train_ys, test_Xs, test_y

train_Xs, train_ys, test_Xs, test_y = makeData('2017-06-16 16:00', 31623, 10)

X_train = np.ascontiguousarray(train_Xs)
y_train = np.ascontiguousarray(train_ys)
X_test = np.ascontiguousarray(test_Xs)
y_test = np.ascontiguousarray(test_y)

# %%
## Let's try a simple SVC model to take care of the logistic regression case as well as some other kernels
## First let's find hyperparameters
## A GridSearchCV isn't going to work well due to the inability for sklearnn to automatically make a time series cv object for this specific dataset.
## TimeSeriesSplit will end up splitting the data into folds where some only have one class (1 or 0), and it will throw an error.
## We will thus make our own grid search with our own validation that is the same procedure as we used for the linear regression previously.
## Parameters we care about are C and kernel
C = [1e-2, 1e-1, 1, 3]
kernel = ['linear', 'rbf', 'sigmoid', 'poly']

## Give a start time for predictions
start_time_to_predict = '2017-06-12 17:00'
## Give an end time for predictions
end_time_to_predict = '2017-06-14 17:00'
## Make a date range of dates to predict
date_range = pd.date_range(start = pd.to_datetime(start_time_to_predict), end = pd.to_datetime(end_time_to_predict), freq = '10min')
## Make a list of stations for which to make predictions (or just predict all in stations from before)
# stations_to_predict = [31623, 31304, 31520, 31242, 31207, 31204, 31635, 31019, 31919, 31047, 31004]
stations_to_predict = [31623]
## Make various time diffs
time_diffs = [10*i for i in range(1,2)]

init_time = datetime.datetime.now()
for kernel_param in kernel:
    for C_param in C:
        ## Make containers for relevant values for evaluation
        predictions = []
        test_ys = []
        coefs_list = []
        acc_scores = []
        ## Make a prediction for various stations
        for prediction_time_diff in time_diffs:
            ## Make a prediction for each time in the date range
            for i, prediction_station in enumerate(stations_to_predict):
                ## Make a prediction for a range of time diffs
                for prediction_time in date_range:
                    try:
                        train_Xs, train_ys, test_Xs, test_y = makeData(prediction_time, prediction_station, prediction_time_diff)
                        svc = SVC(random_state = 1, class_weight='balanced', decision_function_shape='ovr', C = C_param, kernel = kernel_param)
                        svc.fit(train_Xs, train_ys)
                        pred = svc.predict(test_Xs.values.reshape(1,-1))
                        predictions.append(pred)
                        test_ys.append(test_y)
                    except:
                        continue
            acc_score = accuracy_score(test_ys, predictions)
            acc_scores.append(acc_score)
            print('Accuracy score for kernel =', kernel_param, '| C =',C_param, ' =', acc_score, '|||', datetime.datetime.now() - init_time, 'since start...')
# Out:
# Accuracy score for kernel = linear | C = 0.01  = 0.799307958478 ||| 0:00:19.063916 since start...
# Accuracy score for kernel = linear | C = 0.1  = 0.837370242215 ||| 0:00:38.067987 since start...
# Accuracy score for kernel = linear | C = 1  = 0.847750865052 ||| 0:00:57.710729 since start...
# Accuracy score for kernel = linear | C = 3  = 0.847750865052 ||| 0:01:17.660028 since start...
# Accuracy score for kernel = rbf | C = 0.01  = 0.539792387543 ||| 0:01:36.788123 since start...
# Accuracy score for kernel = rbf | C = 0.1  = 0.43598615917 ||| 0:01:55.949038 since start...
# Accuracy score for kernel = rbf | C = 1  = 0.930795847751 ||| 0:02:15.225855 since start...
# Accuracy score for kernel = rbf | C = 3  = 0.937716262976 ||| 0:02:34.355968 since start...
# Accuracy score for kernel = sigmoid | C = 0.01  = 0.356401384083 ||| 0:02:53.776873 since start...
# Accuracy score for kernel = sigmoid | C = 0.1  = 0.425605536332 ||| 0:03:12.872168 since start...
# Accuracy score for kernel = sigmoid | C = 1  = 0.231833910035 ||| 0:03:31.968352 since start...
# Accuracy score for kernel = sigmoid | C = 3  = 0.131487889273 ||| 0:03:51.164412 since start...
# Accuracy score for kernel = poly | C = 0.01  = 0.892733564014 ||| 0:04:10.591431 since start...
# Accuracy score for kernel = poly | C = 0.1  = 0.896193771626 ||| 0:04:30.588238 since start...
# Accuracy score for kernel = poly | C = 1  = 0.899653979239 ||| 0:04:55.585401 since start...
# Accuracy score for kernel = poly | C = 3  = 0.910034602076 ||| 0:05:26.527268 since start...

# %%
## Meh, the results for the SVC are comparable to our linear regression-based classifier, but the SVC takes a lot longer (~1 second versus ~20 seconds)
## Since we don't want the user to have to wait for the result when they click the "plan route" button speed is of paramount importance.
## We'll try a random forest just for kicks and leave it going overnight since it's likely going to take forever to grid search.
## It's speed will also be very slow compare to the linear regression, so this really is just for fun.

# %% [markdown]
# ### Set up the random forest classifier

# %%
## Same situation as before with the grid search and the cv problems
## We will make our own grid search with our own validation that is the same procedure as we used for the linear regression previously.
## Parameters we care about are n_estimators, max_depth, max_features, min_samples_split, min_samples_leaf, min_weight_fraction_leaf, max_leaf_nodes
n_estimators = [10, 100]
max_depth = [6, 10]
max_features = [6]
min_samples_split = [3, 6, 9]
min_samples_leaf = [3, 6, 9]
min_weight_fraction_leaf = [0, 0.25, 0.5]
max_leaf_nodes = [5, 10, 15]

## Give a start time for predictions
start_time_to_predict = '2017-06-12 17:00'
## Give an end time for predictions
end_time_to_predict = '2017-06-14 17:00'
## Make a date range of dates to predict
date_range = pd.date_range(start = pd.to_datetime(start_time_to_predict), end = pd.to_datetime(end_time_to_predict), freq = '10min')
## Make a list of stations for which to make predictions (or just predict all in stations from before)
# stations_to_predict = [31623, 31304, 31520, 31242, 31207, 31204, 31635, 31019, 31919, 31047, 31004]
stations_to_predict = [31623]
## Make various time diffs
time_diffs = [10*i for i in range(1,2)]

init_time = datetime.datetime.now()
for n_estimators_param in n_estimators:
    for max_depth_param in max_depth:
        for max_features_param in max_features:
            for min_samples_split_param in min_samples_split:
                for min_samples_leaf_param in min_samples_leaf:
                    for min_weight_fraction_leaf_param in min_weight_fraction_leaf:
                        for max_leaf_nodes_param in max_leaf_nodes:
                            ## Make containers for relevant values for evaluation
                            predictions = []
                            test_ys = []
                            coefs_list = []
                            acc_scores = []
                            ## Make a prediction for various stations
                            for prediction_time_diff in time_diffs:
                                ## Make a prediction for each time in the date range
                                for i, prediction_station in enumerate(stations_to_predict):
                                    ## Make a prediction for a range of time diffs
                                    for prediction_time in date_range:
                                        try:
                                            train_Xs, train_ys, test_Xs, test_y = makeData(prediction_time, prediction_station, prediction_time_diff)
                                            rfc = RandomForestClassifier(random_state = 1, class_weight='balanced', n_jobs = 8, max_depth = max_depth_param, max_features = max_features_param,
                                                                         min_samples_split = min_samples_split_param, min_samples_leaf = min_samples_leaf_param, 
                                                                         min_weight_fraction_leaf = min_weight_fraction_leaf_param, max_leaf_nodes = max_leaf_nodes_param) 
                                            rfc.fit(train_Xs, train_ys)
                                            pred = rfc.predict(test_Xs.values.reshape(1,-1))
                                            predictions.append(pred)
                                            test_ys.append(test_y)
                                        except:
                                            print('THIS ONE DIDNT WORK: n_estimators =', n_estimators_param, '| max_depth =', max_depth_param, '| max_features =', max_features_param, 
                                                  '| min_samples_split', min_samples_split_param, '| min_samples_leaf', min_samples_leaf_param, "| min_weight_fraction_leaf", 
                                                  min_weight_fraction_leaf_param, '| max_leaf_nodes', max_leaf_nodes_param, '|||', datetime.datetime.now() - init_time, 'since start...')
                                            continue
                                acc_score = accuracy_score(test_ys, predictions)
                                acc_scores.append(acc_score)
                                print('Accuracy score for n_estimators =', n_estimators_param, '| max_depth =', max_depth_param, '| max_features =', max_features_param, 
                                      '| min_samples_split', min_samples_split_param, '| min_samples_leaf', min_samples_leaf_param, "| min_weight_fraction_leaf", 
                                      min_weight_fraction_leaf_param, '| max_leaf_nodes', max_leaf_nodes_param, '| accuracy =', acc_score, '|||', datetime.datetime.now() - init_time, 'since start...')
# Out:
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.882352941176 ||| 0:01:19.116112 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.906574394464 ||| 0:02:38.099951 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.906574394464 ||| 0:03:57.187100 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.826989619377 ||| 0:05:16.164392 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.826989619377 ||| 0:06:35.239336 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.826989619377 ||| 0:07:54.357811 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 0:09:13.366800 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 0:10:32.561384 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 0:11:51.497542 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.892733564014 ||| 0:13:10.440857 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.889273356401 ||| 0:14:29.476725 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.889273356401 ||| 0:15:50.197008 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.809688581315 ||| 0:17:11.269111 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.809688581315 ||| 0:18:32.046145 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.809688581315 ||| 0:19:52.245666 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 0:21:12.507089 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 0:22:33.033200 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 0:23:53.506751 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.847750865052 ||| 0:25:13.785262 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.847750865052 ||| 0:26:34.176611 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.847750865052 ||| 0:27:54.288481 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.799307958478 ||| 0:29:14.980952 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.799307958478 ||| 0:30:35.217794 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.799307958478 ||| 0:31:55.292920 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 0:33:15.263711 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 0:34:35.216155 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 0:35:55.228519 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.882352941176 ||| 0:37:15.219539 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.906574394464 ||| 0:38:35.188641 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.906574394464 ||| 0:39:55.033946 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.826989619377 ||| 0:41:14.910259 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.826989619377 ||| 0:42:34.728054 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.826989619377 ||| 0:43:54.678413 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 0:45:14.580595 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 0:46:34.762252 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 0:47:54.562762 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.892733564014 ||| 0:49:14.415525 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.889273356401 ||| 0:50:34.318824 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.889273356401 ||| 0:51:54.254663 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.809688581315 ||| 0:53:14.150609 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.809688581315 ||| 0:54:35.614204 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.809688581315 ||| 0:55:56.973685 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 0:57:18.224609 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 0:58:39.467730 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 1:00:00.811459 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.847750865052 ||| 1:01:22.101167 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.847750865052 ||| 1:02:43.365698 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.847750865052 ||| 1:04:04.587092 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.799307958478 ||| 1:05:25.997552 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.799307958478 ||| 1:06:47.269307 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.799307958478 ||| 1:08:08.614801 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 1:09:29.933946 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 1:10:51.277237 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 1:12:12.668793 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.885813148789 ||| 1:13:33.961742 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.899653979239 ||| 1:14:55.293761 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.899653979239 ||| 1:16:16.904067 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.826989619377 ||| 1:17:38.516155 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.826989619377 ||| 1:19:00.412025 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.826989619377 ||| 1:20:22.415568 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 1:21:44.090287 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 1:23:04.226546 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 1:24:24.313575 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.892733564014 ||| 1:25:44.551327 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.889273356401 ||| 1:27:04.650456 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.889273356401 ||| 1:28:24.837416 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.809688581315 ||| 1:29:45.100394 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.809688581315 ||| 1:31:05.178708 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.809688581315 ||| 1:32:25.365578 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 1:33:45.308006 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 1:35:05.320420 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 1:36:25.452035 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.847750865052 ||| 1:37:45.480769 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.847750865052 ||| 1:39:05.536588 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.847750865052 ||| 1:40:25.728773 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.799307958478 ||| 1:41:45.786341 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.799307958478 ||| 1:43:05.838313 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.799307958478 ||| 1:44:25.874820 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 1:45:46.159036 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 1:47:06.123398 since start...
# Accuracy score for n_estimators = 10 | max_depth = 6 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 1:48:26.210342 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.882352941176 ||| 1:49:46.336722 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.906574394464 ||| 1:51:06.378776 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.906574394464 ||| 1:52:26.461727 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.826989619377 ||| 1:53:46.630429 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.826989619377 ||| 1:55:06.637257 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.826989619377 ||| 1:56:26.783303 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 1:57:46.801302 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 1:59:06.851135 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 2:00:26.887120 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.892733564014 ||| 2:01:47.007199 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.889273356401 ||| 2:03:06.948014 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.889273356401 ||| 2:04:27.056013 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.809688581315 ||| 2:05:47.147208 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.809688581315 ||| 2:07:07.158791 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.809688581315 ||| 2:08:27.169425 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 2:09:47.128498 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 2:11:07.129351 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 2:12:27.157849 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.847750865052 ||| 2:13:47.119282 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.847750865052 ||| 2:15:06.504030 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.847750865052 ||| 2:16:25.804421 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.799307958478 ||| 2:17:44.752096 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.799307958478 ||| 2:19:03.575034 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.799307958478 ||| 2:20:22.525455 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 2:21:41.498293 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 2:23:00.380633 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 2:24:19.327886 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.882352941176 ||| 2:25:38.340041 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.906574394464 ||| 2:26:57.201430 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.906574394464 ||| 2:28:16.125773 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.826989619377 ||| 2:29:35.112207 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.826989619377 ||| 2:30:53.948463 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.826989619377 ||| 2:32:12.950251 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 2:33:31.888534 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 2:34:50.726666 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 2:36:09.703640 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.892733564014 ||| 2:37:28.717284 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.889273356401 ||| 2:38:47.578755 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.889273356401 ||| 2:40:06.611519 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.809688581315 ||| 2:41:25.571165 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.809688581315 ||| 2:42:44.447100 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.809688581315 ||| 2:44:03.399600 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 2:45:22.417516 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 2:46:41.486758 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 2:48:00.472795 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.847750865052 ||| 2:49:19.370914 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.847750865052 ||| 2:50:38.246023 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.847750865052 ||| 2:51:57.273910 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.799307958478 ||| 2:53:16.122841 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.799307958478 ||| 2:54:35.083929 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.799307958478 ||| 2:55:54.032856 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 2:57:12.889558 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 2:58:31.843818 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 2:59:50.812785 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.885813148789 ||| 3:01:09.656077 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.899653979239 ||| 3:02:28.575793 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.899653979239 ||| 3:03:47.484789 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.826989619377 ||| 3:05:06.311335 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.826989619377 ||| 3:06:25.284983 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.826989619377 ||| 3:07:44.211455 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 3:09:03.091047 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 3:10:22.074253 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 3:11:41.104009 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.892733564014 ||| 3:12:59.944614 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.889273356401 ||| 3:14:18.886014 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.889273356401 ||| 3:15:39.056943 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.809688581315 ||| 3:17:00.158410 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.809688581315 ||| 3:18:20.554869 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.809688581315 ||| 3:19:40.822950 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 3:20:59.920425 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 3:22:18.902808 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 3:23:37.899840 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.847750865052 ||| 3:24:56.777606 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.847750865052 ||| 3:26:15.715654 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.847750865052 ||| 3:27:34.533103 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.799307958478 ||| 3:28:53.475062 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.799307958478 ||| 3:30:12.410720 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.799307958478 ||| 3:31:31.443933 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 3:32:50.347653 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 3:34:09.349718 since start...
# Accuracy score for n_estimators = 10 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 3:35:28.306580 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.882352941176 ||| 3:36:47.152277 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.906574394464 ||| 3:38:06.110712 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.906574394464 ||| 3:39:25.068546 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.826989619377 ||| 3:40:43.956016 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.826989619377 ||| 3:42:03.892265 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.826989619377 ||| 3:43:23.983222 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 3:44:44.065032 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 3:46:04.150088 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 3:47:24.309422 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.892733564014 ||| 3:48:44.383770 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.889273356401 ||| 3:50:04.607242 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.889273356401 ||| 3:51:24.829103 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.809688581315 ||| 3:52:44.917961 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.809688581315 ||| 3:54:05.053692 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.809688581315 ||| 3:55:25.173113 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 3:56:45.234816 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 3:58:04.757805 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 3:59:23.751604 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.847750865052 ||| 4:00:42.618924 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.847750865052 ||| 4:02:01.551406 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.847750865052 ||| 4:03:20.529663 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.799307958478 ||| 4:04:39.366851 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.799307958478 ||| 4:05:58.318576 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.799307958478 ||| 4:07:17.267193 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 4:08:36.157796 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 4:09:55.112665 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 4:11:13.948410 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.882352941176 ||| 4:12:32.934791 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.906574394464 ||| 4:13:51.918882 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.906574394464 ||| 4:15:10.756533 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.826989619377 ||| 4:16:30.014998 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.826989619377 ||| 4:17:48.958267 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.826989619377 ||| 4:19:07.810350 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 4:20:26.807690 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 4:21:45.780380 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 4:23:04.641460 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.892733564014 ||| 4:24:23.585272 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.889273356401 ||| 4:25:42.576572 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.889273356401 ||| 4:27:01.403908 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.809688581315 ||| 4:28:20.365531 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.809688581315 ||| 4:29:39.423296 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.809688581315 ||| 4:30:58.293384 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 4:32:17.266409 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 4:33:36.207471 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 4:34:55.039330 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.847750865052 ||| 4:36:13.968016 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.847750865052 ||| 4:37:32.977238 since start...
# Accuracy score for n_estimators = 100 | max_depth = 6 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.847750865052 ||| 4:38:51.860830 since start...
# ...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.809688581315 ||| 5:39:23.643194 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.809688581315 ||| 5:40:42.464556 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.809688581315 ||| 5:42:01.428974 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 5:43:20.432793 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 5:44:39.301045 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 5:45:58.394428 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.847750865052 ||| 5:47:17.318610 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.847750865052 ||| 5:48:36.261722 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.847750865052 ||| 5:49:55.185550 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.799307958478 ||| 5:51:14.039604 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.799307958478 ||| 5:52:33.011019 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.799307958478 ||| 5:53:51.965674 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 5:55:10.865733 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 5:56:29.888912 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 3 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 5:57:48.843526 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.882352941176 ||| 5:59:07.892201 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.906574394464 ||| 6:00:26.910503 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.906574394464 ||| 6:01:45.882369 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.826989619377 ||| 6:03:04.713436 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.826989619377 ||| 6:04:23.622562 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.826989619377 ||| 6:05:42.601444 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 6:07:01.477276 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 6:08:20.449556 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 6:09:39.468486 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.892733564014 ||| 6:10:58.324715 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.889273356401 ||| 6:12:17.281742 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.889273356401 ||| 6:13:36.271893 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.809688581315 ||| 6:14:55.194262 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.809688581315 ||| 6:16:14.361400 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.809688581315 ||| 6:17:33.330378 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 6:18:52.222220 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 6:20:11.203726 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 6:21:30.194239 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.847750865052 ||| 6:22:49.027692 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.847750865052 ||| 6:24:07.970721 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.847750865052 ||| 6:25:26.941971 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.799307958478 ||| 6:26:45.749190 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.799307958478 ||| 6:28:04.729628 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.799307958478 ||| 6:29:23.732706 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 6:30:42.583197 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 6:32:01.491848 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 6 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 6:33:20.461944 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.885813148789 ||| 6:34:39.337635 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.899653979239 ||| 6:35:58.272601 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.899653979239 ||| 6:37:17.251665 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.826989619377 ||| 6:38:36.175963 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.826989619377 ||| 6:39:55.143449 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.826989619377 ||| 6:41:14.008924 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 6:42:32.996148 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 6:43:51.926658 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 3 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 6:45:10.786908 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.892733564014 ||| 6:46:30.009505 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.889273356401 ||| 6:47:49.010954 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.889273356401 ||| 6:49:07.854020 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.809688581315 ||| 6:50:26.780174 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.809688581315 ||| 6:51:45.803477 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.809688581315 ||| 6:53:04.691385 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 6:54:23.717653 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 6:55:42.668677 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 6 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 6:57:01.604481 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 5 | accuracy = 0.847750865052 ||| 6:58:20.529553 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 10 | accuracy = 0.847750865052 ||| 6:59:39.468525 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0 | max_leaf_nodes 15 | accuracy = 0.847750865052 ||| 7:00:58.318680 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 5 | accuracy = 0.799307958478 ||| 7:02:17.254222 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 10 | accuracy = 0.799307958478 ||| 7:03:36.238532 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.25 | max_leaf_nodes 15 | accuracy = 0.799307958478 ||| 7:04:55.125735 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 5 | accuracy = 0.629757785467 ||| 7:06:14.123073 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 10 | accuracy = 0.629757785467 ||| 7:07:33.147403 since start...
# Accuracy score for n_estimators = 100 | max_depth = 10 | max_features = 6 | min_samples_split 9 | min_samples_leaf 9 | min_weight_fraction_leaf 0.5 | max_leaf_nodes 15 | accuracy = 0.629757785467 ||| 7:08:51.970428 since start...

# %%
## As predicted the random forest model did similarly on accuracy for some parameter combinations but took forever to run compared to the linear regression.

# %%
## Let's just do a simple auto-sklearn regressor to see if we can improve upon the regression strategy without losing much speed.
## Make the data sets
def makeRegressorData(time_to_predict, station, time_difference):
    ## Convert time_to_predict into datetime
    datetime_to_predict = pd.to_datetime(time_to_predict)

    ## Get data for training the model
    ## Make date range to get values for the day a week prior to the query
    ############## USE THIS FOR TESTING UNTIL ENOUGH DATA ARE ACQUIRED, THEN CHANGE FROM 1 DAY TO 7 DAYS PRIOR ####################
    start_time = datetime_to_predict - datetime.timedelta(hours = 24)
    end_time = datetime_to_predict

    ## Make container for data
    train_Xs = []
    train_ys = []
    ## Get data from the dataframe for a station between two times passed in as datetime objects.
    temp_df = pd.DataFrame(df[start_time:end_time][station])
    temp_df.columns = ['y']
            
    ## Make lag features
    number_of_lags = 6
    ## Add lags
    for i in range(1,number_of_lags+1):
        temp_df['lag_'+str(10*i+time_difference)] = temp_df.y.shift(int(i+time_difference/10))
    ## Drop NAs
    temp_df.dropna(inplace = True, axis = 0)
    ## Return X and y values
    temp_Xs = temp_df.drop('y', axis = 1)
    temp_ys = temp_df.y

    ## Get data for making the prediction
    train_Xs = temp_Xs.iloc[:-1, :]
    train_ys = temp_ys.iloc[:-1]
    test_Xs = temp_Xs.iloc[-1, :]
    test_y = temp_ys.iloc[-1]
        
    return train_Xs, train_ys, test_Xs, test_y

train_Xs, train_ys, test_Xs, test_y = makeRegressorData('2017-06-16 16:00', 31623, 10)

X_train = np.ascontiguousarray(train_Xs)
y_train = np.ascontiguousarray(train_ys)
X_test = np.ascontiguousarray(test_Xs)
y_test = np.ascontiguousarray(test_y)

automl = AutoSklearnRegressor(time_left_for_this_task=3600, per_run_time_limit=360, ml_memory_limit=16384)
automl.fit(X_train, y_train)
# Out:
# [WARNING] [2017-06-17 12:46:07,517:AutoMLSMBO(1)::1c0cf9cf879c164af66733d2f50416cf] Could not find meta-data directory /usr/lib64/python3.5/site-packages/autosklearn/metalearning/files/r2_regression_dense
# You are already timing task: index_run6
# You are already timing task: index_run10
# You are already timing task: index_run10
# You are already timing task: index_run11
# [WARNING] [2017-06-17 12:48:33,592:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2017-06-17 12:48:33,592:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# You are already timing task: index_run11
# You are already timing task: index_run11
# You are already timing task: index_run11
# You are already timing task: index_run11
# You are already timing task: index_run11
# You are already timing task: index_run11
# You are already timing task: index_run11
# You are already timing task: index_run11
# You are already timing task: index_run11
# You are already timing task: index_run11
# You are already timing task: index_run12
# You are already timing task: index_run13
# [WARNING] [2017-06-17 12:49:07,014:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2017-06-17 12:49:07,014:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# You are already timing task: index_run13
# You are already timing task: index_run13
# You are already timing task: index_run13
# You are already timing task: index_run13
# You are already timing task: index_run14
# You are already timing task: index_run14
# You are already timing task: index_run14
# You are already timing task: index_run14
# You are already timing task: index_run17
# You are already timing task: index_run19
# You are already timing task: index_run20
# You are already timing task: index_run20
# You are already timing task: index_run20
# You are already timing task: index_run20
# You are already timing task: index_run20
# You are already timing task: index_run21
# You are already timing task: index_run21
# You are already timing task: index_run21
# You are already timing task: index_run21
# You are already timing task: index_run22
# You are already timing task: index_run22
# You are already timing task: index_run22
# You are already timing task: index_run22
# You are already timing task: index_run22
# You are already timing task: index_run23
# You are already timing task: index_run23
# You are already timing task: index_run24
# You are already timing task: index_run25
# You are already timing task: index_run26
# You are already timing task: index_run27
# You are already timing task: index_run27
# You are already timing task: index_run27
# You are already timing task: index_run27
# You are already timing task: index_run28
# You are already timing task: index_run28
# You are already timing task: index_run28
# You are already timing task: index_run28
# You are already timing task: index_run28
# You are already timing task: index_run28
# You are already timing task: index_run28
# You are already timing task: index_run28
# You are already timing task: index_run28
# You are already timing task: index_run28
# You are already timing task: index_run28
# You are already timing task: index_run28
# You are already timing task: index_run29
# You are already timing task: index_run29
# You are already timing task: index_run30
# You are already timing task: index_run30
# You are already timing task: index_run30
# You are already timing task: index_run30
# You are already timing task: index_run30
# You are already timing task: index_run30
# You are already timing task: index_run30
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run31
# You are already timing task: index_run32
# You are already timing task: index_run32
# You are already timing task: index_run32
# You are already timing task: index_run32
# You are already timing task: index_run32
# You are already timing task: index_run32
# You are already timing task: index_run32
# You are already timing task: index_run32
# You are already timing task: index_run32
# You are already timing task: index_run32
# You are already timing task: index_run32
# You are already timing task: index_run32
# You are already timing task: index_run33
# You are already timing task: index_run33
# You are already timing task: index_run33
# You are already timing task: index_run33
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# [WARNING] [2017-06-17 12:58:31,467:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# [WARNING] [2017-06-17 12:58:31,467:smac.intensification.intensification.Intensifier] Challenger was the same as the current incumbent; Skipping challenger
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run34
# You are already timing task: index_run35
# You are already timing task: index_run35
# You are already timing task: index_run35
# You are already timing task: index_run35
# You are already timing task: index_run35
# You are already timing task: index_run35
# You are already timing task: index_run35
# You are already timing task: index_run35
# You are already timing task: index_run35
# You are already timing task: index_run35
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run36
# You are already timing task: index_run37
# You are already timing task: index_run37
# You are already timing task: index_run37
# You are already timing task: index_run37
# You are already timing task: index_run37
# You are already timing task: index_run37
# You are already timing task: index_run37
# You are already timing task: index_run37
# You are already timing task: index_run37
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run38
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run39
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run40
# You are already timing task: index_run41
# You are already timing task: index_run41
# You are already timing task: index_run41
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run42
# You are already timing task: index_run43
# You are already timing task: index_run43
# You are already timing task: index_run43
# You are already timing task: index_run43
# You are already timing task: index_run43
# You are already timing task: index_run43
# You are already timing task: index_run43
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run44
# You are already timing task: index_run45
# You are already timing task: index_run45
# You are already timing task: index_run45
# You are already timing task: index_run45
# You are already timing task: index_run45
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run46
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run47
# You are already timing task: index_run48
# You are already timing task: index_run48
# You are already timing task: index_run48
# You are already timing task: index_run48

# %%
def makeAutoSklearnPrediction(time_to_predict, station, time_difference):
    ## Convert time_to_predict into datetime
    datetime_to_predict = pd.to_datetime(time_to_predict)

    ## Get data for training the model
    ## Make date range to get values for the day a week prior to the query
    ############## USE THIS FOR TESTING UNTIL ENOUGH DATA ARE ACQUIRED, THEN CHANGE FROM 1 DAY TO 7 DAYS PRIOR ####################
    start_time = datetime_to_predict - datetime.timedelta(hours = 24)
    end_time = datetime_to_predict

    ## Make container for data
    train_Xs = []
    train_ys = []
    ## Get data from the dataframe for a station between two times passed in as datetime objects.
    temp_df = pd.DataFrame(df[start_time:end_time][station])
    temp_df.columns = ['y']
            
    ## Make lag features
    number_of_lags = 6
    ## Add lags
    for i in range(1,number_of_lags+1):
        temp_df['lag_'+str(10*i+time_difference)] = temp_df.y.shift(int(i+time_difference/10))
    ## Drop NAs
    temp_df.dropna(inplace = True, axis = 0)
    ## Return X and y values
    temp_Xs = temp_df.drop('y', axis = 1)
    temp_ys = temp_df.y

    ## Get data for making the prediction
    train_Xs = temp_Xs.iloc[:-1, :]
    train_ys = temp_ys.iloc[:-1]
    test_Xs = temp_Xs.iloc[-1, :]
    test_y = temp_ys.iloc[-1]
    
    X_train = np.ascontiguousarray(train_Xs)
    y_train = np.ascontiguousarray(train_ys)
    X_test = np.ascontiguousarray(test_Xs)
    y_test = np.ascontiguousarray(test_y)
    
    features = train_Xs.columns

    ## Make a prediction for the time in question
    prediction = int(np.round(automl.predict(np.array(X_test).reshape(1,-1))))
    ## return the prediction and the actual value
    return prediction, test_y, features

def makeAutoSklearnPlot(preds, actual_vals, feature_names):
    ## Convert the list of arrays each with a single value to a list of values
    lr_variance = r2_score(actual_vals, preds)
    lr_rmse = np.sqrt(mean_squared_error(actual_vals, preds))
    lr_r = sp.stats.pearsonr(actual_vals, preds)[0]

    sns.set(font_scale = 2)
    fig = plt.figure(figsize = [14, 7])
    plt.subplot(1,2,1)
    plt.scatter(actual_vals, preds)
    plt.title('Predictions vs actual values')
    plt.ylabel('Predicted number of rides')
    plt.xlabel('Actual number of rides')
    plt.annotate('r = '+str(sp.stats.pearsonr(actual_vals, preds)[0])+"\nR^2 = "+str(lr_variance)+"\nRMSE = "+str(lr_rmse), xy=(0.05, 0.78), xycoords='axes fraction', size = 20)
    plt.tight_layout()
    plt.subplot(1,2,2)
    plt.plot(actual_vals)
    plt.plot(preds)
    plt.title('Bike availability over time')
    plt.xlabel('Time point index')
    plt.ylabel('Number of bikes\n(green = predicted)')
    plt.annotate('% accuracy = '+str(eval_metric(actual_vals, preds,2)), xy=(0.05, 0.94), xycoords='axes fraction', size = 20)
    plt.tight_layout()

## Give a start time for predictions
start_time_to_predict = '2017-06-12 17:00'
## Give an end time for predictions
end_time_to_predict = '2017-06-14 17:00'
## Make a date range of dates to predict
date_range = pd.date_range(start = pd.to_datetime(start_time_to_predict), end = pd.to_datetime(end_time_to_predict), freq = '10min')
## Make a list of stations for which to make predictions (or just predict all in stations from before)
# stations_to_predict = [31623, 31304, 31520, 31242, 31207, 31204, 31635, 31019, 31919, 31047, 31004]
stations_to_predict = [31623]
## Make various time diffs
time_diffs = [10*i for i in range(1,2)]

## Make containers for relevant values for evaluation
predictions = []
test_ys = []
coefs_list = []
## Make a prediction for various stations
init_time = datetime.datetime.now()
for i, prediction_station in enumerate(stations_to_predict):
    temp_dict = {}
    ## Make a prediction for a range of time diffs
    for prediction_time_diff in time_diffs:
        ## Make a prediction for each time in the date range
        for prediction_time in date_range:
            pred, actual_value, features = makeAutoSklearnPrediction(prediction_time, prediction_station, prediction_time_diff)
            predictions.append(pred)
            test_ys.append(actual_value)
#             coefs_list.append(lr.coef_)
    print('Done with station', i+1, 'of', len(stations_to_predict), '-', datetime.datetime.now() - init_time, 'since start.')

makeAutoSklearnPlot(predictions, test_ys, features)
# Out:
# Done with station 1 of 1 - 0:00:09.601037 since start.

# %%
## The 1-hour auto-sklearn didn't produce anything better than our linear regression model.
## Overall the simple linear regression works the best for our specific case. It's always nice when things can be kept simple.
